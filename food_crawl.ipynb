# %% [markdown]
# ## Food & Health
# - 랭크 넘버 대신 오특 이라고 써진 삽입 제품 처리 -> 직전 rank 값 저장 후 rank 데이터 없는 상품일때 직전 rank 값 +1 , 오특이라는 값을 flag 리스트에 추가

# %% [markdown]
# ### Food

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep

browser = webdriver.Chrome()

url = "https://www.oliveyoung.co.kr/store/main/getBestList.do?dispCatNo=900000100100001&fltDispCatNo=10000020002&pageIdx=1&rowsPerPage=100&t_page=%EB%9E%AD%ED%82%B9&t_click=%ED%8C%90%EB%A7%A4%EB%9E%AD%ED%82%B9_%ED%91%B8%EB%93%9C"
browser.get(url)
sleep(5)

soup = BeautifulSoup(browser.page_source, "html.parser")
itemList = soup.select('.TabsConts.on > ul > li')

dataSave = []
rank_num = 0  # 초기 rank 값

for i, item in enumerate(itemList):
    print(f"\n▶ {i+1}번째 아이템 처리 중...")

    # ▶ rank
    rank_tag = item.select('span.thumb_flag.best')
    if rank_tag:
        rank = int(rank_tag[0].text.strip())
        is_special = False
    else:
        rank = rank_num + 1
        is_special = True
    rank_num = rank

    brandName = item.select('span.tx_brand')[0].text.strip()
    isPb = 1 if brandName == '딜라이트 프로젝트' else 0
    goodsName = item.select('p.tx_name')[0].text.strip()
    salePrice = item.select('p.prd_price > span.tx_cur > span.tx_num')[0].text.strip()

    org_tag = item.select('p.prd_price > span.tx_org > span.tx_num')
    originalPrice = org_tag[0].text.strip() if org_tag else salePrice

    flag_tags = item.select('p.prd_flag > span.icon_flag')
    flagList = [tag.text.strip() for tag in flag_tags] if flag_tags else []
    if is_special:
        flagList.append('오특')

    data = {
        'rank': rank,
        'brandName': brandName,
        'isPb': isPb,
        'goodsName': goodsName,
        'salePrice': salePrice,
        'originalPrice': originalPrice,
        'flagList': flagList
    }

    link_tag = item.select_one('a.prd_thumb')
    goodsUrl = link_tag['href'] if link_tag and 'href' in link_tag.attrs else ''

    if goodsUrl:
        browser.get(goodsUrl)
        sleep(3)

        try:
            review_btn = browser.find_element("css selector", 'li#reviewInfo a.goods_reputation')
            review_btn.click()
            sleep(2)

            detail_soup = BeautifulSoup(browser.page_source, "html.parser")

            # ▶ 필수 리뷰 정보 (예외처리 없이 바로 추출)
            totalComment = detail_soup.select_one('p.img_face > em').text.strip()
            numOfReviews = detail_soup.select_one('p.total > em').text.strip()

            li_tags = detail_soup.select('ul.graph_list > li > span.per')
            pctOf5 = int(li_tags[0].get_text(strip=True).replace('%', ''))
            pctOf4 = int(li_tags[1].get_text(strip=True).replace('%', ''))
            pctOf3 = int(li_tags[2].get_text(strip=True).replace('%', ''))
            pctOf2 = int(li_tags[3].get_text(strip=True).replace('%', ''))
            pctOf1 = int(li_tags[4].get_text(strip=True).replace('%', ''))

            # ▶ 선택 리뷰 영역 (없을 수도 있음)
            packing_data = {'pakingGood': 0, 'pakingMiddle': 0, 'pakingBad': 0}
            exp_data = {'expLong': 0, 'expMiddle': 0, 'expShort': 0}
            taste_data = {'tasteGood': 0, 'tasteMiddle': 0, 'tasteBad': 0}

            review_list = detail_soup.select('div.poll_all.clrfix > .poll_type2.type3')
            if len(review_list) >= 3:
                categories = [
                    ('paking', ['Good', 'Middle', 'Bad']),
                    ('exp', ['Long', 'Middle', 'Short']),
                    ('taste', ['Good', 'Middle', 'Bad'])
                ]

                for idx, (prefix, suffixes) in enumerate(categories):
                    item_list = review_list[idx].select('dd li')
                    for i, suffix in enumerate(suffixes):
                        key = f"{prefix}{suffix}"
                        try:
                            value = int(item_list[i].select_one('em').get_text(strip=True).replace('%', ''))
                        except:
                            value = 0
                        if prefix == 'paking':
                            packing_data[key] = value
                        elif prefix == 'exp':
                            exp_data[key] = value
                        elif prefix == 'taste':
                            taste_data[key] = value
            else:
                print("→ 상세 리뷰 항목 없음 (packing/exp/taste)")

            # ▶ 상세정보 저장
            data.update({
                'totalComment': totalComment,
                'numOfReviews': numOfReviews,
                'pctOf5': pctOf5,
                'pctOf4': pctOf4,
                'pctOf3': pctOf3,
                'pctOf2': pctOf2,
                'pctOf1': pctOf1,
                **packing_data,
                **exp_data,
                **taste_data
            })

            print(f"✓ 리뷰 데이터 수집 완료: {goodsName}")

        except Exception as e:
            print(f"[오류] 리뷰 탭 클릭 또는 파싱 실패: {e}")
            # pctOf 계열은 무조건 있다고 가정하므로, 에러 시엔 빈값만 설정
            data.update({
                'pakingGood': 0, 'pakingMiddle': 0, 'pakingBad': 0,
                'expLong': 0, 'expMiddle': 0, 'expShort': 0,
                'tasteGood': 0, 'tasteMiddle': 0, 'tasteBad': 0
            })

    dataSave.append(data)

# ▶ DataFrame 생성
raw_food = pd.DataFrame(dataSave)

# ▶ 브라우저 종료
browser.quit()
# Out:
# ▶ 1번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 프로티원 단백질쉐이크 파우치형 40g 5종 산리오
#
# ▶ 2번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽/띠부씰 포함] 딜라이트 프로젝트 베이글칩 6종 택1 (산리오 에디션)
#
# ▶ 3번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽/1+1] 딜라이트 프로젝트 단백질쉐이크 4종 택1 (산리오 에디션)
#
# ▶ 4번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 딜라이트 프로젝트 베이글칩&단백질쉐이크 (산리오 에디션)
#
# ▶ 5번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 45g 9종 택1
#
# ▶ 6번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 단백질쉐이크 단품/7개입 8종 택1
#
# ▶ 7번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 파워팩 단독] 랩노쉬 단백쿠키 40g 더블초코 더블 기획 외 4종
#
# ▶ 8번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 피넛버터 45g
#
# ▶ 9번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 쿠키앤크림 45g
#
# ▶ 10번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [단독기획/1+1] 플라이밀 단백질쉐이크 쿠키앤크림, 피넛버터 45g 2종
#
# ▶ 11번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 베이글칩 7종 택1
#
# ▶ 12번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 딜라이트 프로젝트 명인 찹쌀오징어채부각 50g 2종 택1 (오리지널/청양마요)
#
# ▶ 13번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월올영픽/1+1] 빼바 소프트 크런치 프로틴바 2종 산리오캐릭터즈 태닝 헬로키티
#
# ▶ 14번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7/1 하루특가] 라이블링 클렌즈 15ml*30포입 유리컵 기획 (5종 택 1)
#
# ▶ 15번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 프로티원 단백질쉐이크 파우치형 40g 4종
#
# ▶ 16번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 티젠 콤부차 레몬/매실/피치/스트로베리키위 10T 기획 (+티코스터) (산리오) (2507)
#
# ▶ 17번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [온라인단독] 딜라이트 프로젝트 베이글칩 5입 선물세트
#
# ▶ 18번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [고함량 진짜 애사비/당류 0g] 글루어트 애플사이다비니거 7종 택 1(단품/기획)
#
# ▶ 19번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월올영픽/2+1] 빼바 리얼초콜릿 프로틴바 3종 산리오캐릭터즈 태닝 헬로키티
#
# ▶ 20번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 라이블링 클렌즈 15ml*10포입 4종 택 1(레몬,청사과,자몽 매실)
#
# ▶ 21번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [사나 Pick] 니아르 브이케어 14정 (7일분) 2종 (파인애플맛/자몽맛)
#
# ▶ 22번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 프레첼 70g 3종 택1 (어니언치즈/버터갈릭/머스타드)
#
# ▶ 23번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 에치와이 갓비움 야쿠르트 100ml
#
# ▶ 24번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 낫띵베럴 럽티 호박차 15입
#
# ▶ 25번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [보틀증정/무료배송] 프로티원 단백질쉐이크 490g x2통
#
# ▶ 26번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [신상출시] 딜라이트 프로젝트 곤약워터젤리 6종 택1
#
# ▶ 27번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월올영픽]테일러 푸룬 딥워터 180ml 5종 (오리지널/레몬/매실/콤부차/자몽)
#
# ▶ 28번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 에치와이 갓비움 푸룬 100ml
#
# ▶ 29번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 딜라이트 프로젝트 명인 부각 3종 택1 (김부각/콩마요김부각/연근부각)
#
# ▶ 30번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 티트리트 푸룬 딥스트롱 180ml
#
# ▶ 31번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [SINCE 1997/급찐급빠] 그린몬스터 헐리우드48시간 원조 클렌즈
#
# ▶ 32번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [무료배송] 플라이밀 단백질쉐이크 630g*2통
#
# ▶ 33번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽/단독]테일러 딥워터 레몬 180ml
#
# ▶ 34번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [2+1/제로슈가] 빼바 리얼초콜릿 프로틴바 40g 1BOX(9개입) (다크/화이트/쿠키앤크림)
#
# ▶ 35번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 베이글칩 8종 택1 (민화 Edition)
#
# ▶ 36번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 명인 부각 단품/세트 8종 택1
#
# ▶ 37번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 빙그레 더단백 팝칩 3종(군옥수수, 매콤살사, 허니갈릭) 택 1
#
# ▶ 38번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 티젠 콤부차 파인애플/샤인머스켓/청귤라임 10T 기획 (+2T) (산리오) (2507)
#
# ▶ 39번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽/고함량 애사비] 글루어트 애플사이다비니거 7종 택 1 (단품/기획)
#
# ▶ 40번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 초코맛 45g
#
# ▶ 41번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 브라운 곡물맛 45g
#
# ▶ 42번째 아이템 처리 중...
# → 상세 리뷰 항목 없음 (packing/exp/taste)
# ✓ 리뷰 데이터 수집 완료: 봄날엔 초코퐁당 요거꿀떡 6입
#
# ▶ 43번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [무료배송] 플라이밀 단백질 쉐이크 대용량 630g (9종)
#
# ▶ 44번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 압타밀 프로푸트라 듀오어드밴스 4종 중 택1 (1~3단계)
#
# ▶ 45번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 디다 디다샷 14포 (2주분)
#
# ▶ 46번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 베이글칩 모음전
#
# ▶ 47번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [신상출시] 딜라이트 프로젝트 곤약워터젤리 단품/10개입 12종 택1
#
# ▶ 48번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 오설록 웨하스 종합세트 (녹차2개+얼그레이2개) (쇼핑백 포함)
#
# ▶ 49번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 블랙 흑임자맛 45g
#
# ▶ 50번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [NEW] 플라이밀 단백질쉐이크 콘시리얼맛 45g
#
# ▶ 51번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 크리스탈라이트 에이드 10p 6종 택1
#
# ▶ 52번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 옐로욜로 카카오칩 25g
#
# ▶ 53번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 고구마맛 45g
#
# ▶ 54번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 오설록 녹차와플x3 + 세작 1입 세트
#
# ▶ 55번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [온라인단독] 딜라이트 프로젝트 단백질쉐이크 540g 4종 택1
#
# ▶ 56번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 라이블링 파인쏙 클렌즈 매실맛 15ml*10포입 ( 파인애플식초)
#
# ▶ 57번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 티젠 애플사이다비니거 5g 30포
#
# ▶ 58번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 낫띵베럴 드링킷 유기농 호박즙 100ml
#
# ▶ 59번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 디다 디다톡 20정 (10일분)
#
# ▶ 60번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [스우파 오죠갱PICK] 딜라이트 프로젝트 애플코코 소보로 베이글칩 50g
#
# ▶ 61번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [1+1/제로슈가] 빼바 소프트 크런치 프로틴바 카카오/솔티드피넛버터 40g 1BOX (9개입)
#
# ▶ 62번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 쫀득한 말랭이 3종 택1 (군고구마/망고/복숭아)
#
# ▶ 63번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 플립즈 솔티드카라멜 프레젤 90g
#
# ▶ 64번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 프로틴 베이커리칩 50g 2종 택1 (브라우니/카스테라)
#
# ▶ 65번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 클룹 애사비 소다 오리지널 500ml
#
# ▶ 66번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [올영단독] 스위치온 단백질 쉐이크 곡물맛 40g
#
# ▶ 67번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [당0g대] 크런틴 크런치볼 단백질쉐이크 초코이즈백 50g
#
# ▶ 68번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 플라이밀 단백질쉐이크 그린 녹차맛 45g
#
# ▶ 69번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 롯데칠성 게토레이 레몬 (240ml x 30)
#
# ▶ 70번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 바삭한 원물칩 3종 택1
#
# ▶ 71번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [리뷰이벤트] 링글스 애사비 캔디 28정 2주분
#
# ▶ 72번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [사나 Pick] 니아르 브이케어 파인애플맛 28정 (14일분)
#
# ▶ 73번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [7월 올영픽] 테일러 푸룬 농축 딥워터 180ml
#
# ▶ 74번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 비브리브 꼬박꼬밥 5종 중 택1(미숫가루,초코,스윗콘,흑임자,딸기)
#
# ▶ 75번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [정희원박사 개발참여]단백하니 프로틴바 3종 택1
#
# ▶ 76번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 부샤드 초콜릿 132g 4종 중 택1 (밀크/다크/카라멜&씨솔트/다크민트)
#
# ▶ 77번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 비비카 구카누가크래커100g 2종 택1 (오리지널,솔티커피)
#
# ▶ 78번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 빨미까레 3종 택1 (저당초코/스트로베리/더블쿠키)
#
# ▶ 79번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [사나 Pick] 니아르 브이케어 28정 (14일분) 2종 (파인애플맛/자몽맛)
#
# ▶ 80번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [차주영 PICK] 비비랩 유기농 레몬즙 10포 3종 택1 (레몬즙/레몬자몽즙/레몬애사비)
#
# ▶ 81번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [사나 Pick] 니아르 퓨어 애사비 28정 (14일분)
#
# ▶ 82번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 델리스푼 잇더핏 더블초코맛 40g 7개입
#
# ▶ 83번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 니아르 가르시니아 샤인머스캣맛 14정 (7일분)
#
# ▶ 84번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 벌꿀약과 2종 택1 (오리지널/눈꽃)
#
# ▶ 85번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 랩노쉬 단백쿠키 4종 택1(더블초코,피넛버터,리치코코넛,화이트오렌지)
#
# ▶ 86번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [사나 Pick] 니아르 브이케어 파인애플맛 14정 (7일분)
#
# ▶ 87번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [본사직영] 코카콜라 무라벨 370ml*24페트
#
# ▶ 88번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 프롬잇 프로틴칩 6종(칠리바베큐,어니언랜치,허니갈릭,콘소메,콰트로치즈,명란마요) 택1
#
# ▶ 89번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 오설록 제주 말차 밀크티 10입
#
# ▶ 90번째 아이템 처리 중...
# → 상세 리뷰 항목 없음 (packing/exp/taste)
# ✓ 리뷰 데이터 수집 완료: 봄날엔 초코초꾸떡 6입
#
# ▶ 91번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 트윅스 탑 초콜릿 비스킷 10개입
#
# ▶ 92번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [힙응비pick] 가벼운 쏙차 15+5포, 당차 15포, 빼차 15포 택1 (오르조,자몽맛,레몬맛)
#
# ▶ 93번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 베노프  단백질쉐이크 600g 7종 택1
#
# ▶ 94번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 플립즈 밀크 초콜릿 프레젤 90g
#
# ▶ 95번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 딜라이트 프로젝트 쫀득한 말랭이 대용량 3종 택1 (군고구마/망고/복숭아)
#
# ▶ 96번째 아이템 처리 중...
# → 상세 리뷰 항목 없음 (packing/exp/taste)
# ✓ 리뷰 데이터 수집 완료: [온브릭스] 신선함을 담은, 항공직송 워싱턴 생체리
#
# ▶ 97번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: [매일유업] 앱솔루트 유기농 궁 분유 1단계(0~6개월) 800g 3캔
#
# ▶ 98번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 오설록 말차 프레첼 대용량 (125g)
#
# ▶ 99번째 아이템 처리 중...
# ✓ 리뷰 데이터 수집 완료: 랩노쉬 저당 웨하스 53g 2종(초코바닐라/초코딸기) 택1
#
# ▶ 100번째 아이템 처리 중...
# → 상세 리뷰 항목 없음 (packing/exp/taste)
# ✓ 리뷰 데이터 수집 완료: [온브릭스] 고당도 부사사과 4kg이상(로열과/18-20입)

# %%
raw_food
# Out:
#     rank  brandName  isPb                                       goodsName  \
# 0      1       프로티원     0                     프로티원 단백질쉐이크 파우치형 40g 5종 산리오
# 1      2  딜라이트 프로젝트     1  [7월 올영픽/띠부씰 포함] 딜라이트 프로젝트 베이글칩 6종 택1 (산리오 에디션)
# 2      3  딜라이트 프로젝트     1   [7월 올영픽/1+1] 딜라이트 프로젝트 단백질쉐이크 4종 택1 (산리오 에디션)
# 3      4  딜라이트 프로젝트     1        [7월 올영픽] 딜라이트 프로젝트 베이글칩&단백질쉐이크 (산리오 에디션)
# 4      5       플라이밀     0                  [7월 올영픽] 플라이밀 단백질쉐이크 45g 9종 택1
# ..   ...        ...   ...                                             ...
# 95    96       온브릭스     0                    [온브릭스] 신선함을 담은, 항공직송 워싱턴 생체리
# 96    97       매일유업     0         [매일유업] 앱솔루트 유기농 궁 분유 1단계(0~6개월) 800g 3캔
# 97    98        오설록     0                           오설록 말차 프레첼 대용량 (125g)
# 98    99        랩노쉬     0                랩노쉬 저당 웨하스 53g 2종(초코바닐라/초코딸기) 택1
# 99   100       온브릭스     0               [온브릭스] 고당도 부사사과 4kg이상(로열과/18-20입)
#
#    salePrice originalPrice         flagList totalComment numOfReviews  pctOf5  \
# 0      3,900         3,900      [1+1, 오늘드림]           최고       29,223      87
# 1      2,430         2,700  [2+1, 쿠폰, 오늘드림]           최고          138      88
# 2      3,900         3,900      [1+1, 오늘드림]           최고           39     100
# 3      2,430         2,700  [2+1, 쿠폰, 오늘드림]           최고           25      92
# 4      3,900         3,900      [1+1, 오늘드림]           최고       39,368      85
# ..       ...           ...              ...          ...          ...     ...
# 95    18,960        23,700         [쿠폰, 무배]           최고           31      97
# 96   105,000       105,000               []           최고           26     100
# 97     7,350        10,500       [세일, 오늘드림]           최고        1,166      77
# 98     3,500         3,500      [2+1, 오늘드림]           최고        5,704      89
# 99    49,920        62,400         [쿠폰, 무배]           최고          120      91
#
#     ...  pctOf1  pakingGood  pakingMiddle  pakingBad  expLong  expMiddle  \
# 0   ...       1          72            28          0       72         28
# 1   ...       0          74            26          0       70         30
# 2   ...       0          74            26          0       64         36
# 3   ...       0          80            20          0       64         36
# 4   ...       1          70            30          0       63         37
# ..  ...     ...         ...           ...        ...      ...        ...
# 95  ...       0           0             0          0        0          0
# 96  ...       0          96             4          0       88         12
# 97  ...       2          74            26          0       64         36
# 98  ...       0          71            29          1       68         32
# 99  ...       0           0             0          0        0          0
#
#     expShort  tasteGood  tasteMiddle  tasteBad
# 0          0         66           34         0
# 1          0         75           25         0
# 2          0         82           18         0
# 3          0         76           24         0
# 4          1         68           30         2
# ..       ...        ...          ...       ...
# 95         0          0            0         0
# 96         0         88           12         0
# 97         0         63           28         9
# 98         0         76           24         1
# 99         0          0            0         0
#
# [100 rows x 23 columns]

# %%
raw_food.to_csv('20250701_raw_food.csv', index=False)

# %%
driver.quit()

# %%
dd = pd.read_csv('20250701_raw_food.csv')
dd
# Out:
#     rank  brandName  isPb                                       goodsName  \
# 0      1       프로티원     0                     프로티원 단백질쉐이크 파우치형 40g 5종 산리오
# 1      2  딜라이트 프로젝트     1  [7월 올영픽/띠부씰 포함] 딜라이트 프로젝트 베이글칩 6종 택1 (산리오 에디션)
# 2      3  딜라이트 프로젝트     1   [7월 올영픽/1+1] 딜라이트 프로젝트 단백질쉐이크 4종 택1 (산리오 에디션)
# 3      4  딜라이트 프로젝트     1        [7월 올영픽] 딜라이트 프로젝트 베이글칩&단백질쉐이크 (산리오 에디션)
# 4      5       플라이밀     0                  [7월 올영픽] 플라이밀 단백질쉐이크 45g 9종 택1
# ..   ...        ...   ...                                             ...
# 95    96       온브릭스     0                    [온브릭스] 신선함을 담은, 항공직송 워싱턴 생체리
# 96    97       매일유업     0         [매일유업] 앱솔루트 유기농 궁 분유 1단계(0~6개월) 800g 3캔
# 97    98        오설록     0                           오설록 말차 프레첼 대용량 (125g)
# 98    99        랩노쉬     0                랩노쉬 저당 웨하스 53g 2종(초코바닐라/초코딸기) 택1
# 99   100       온브릭스     0               [온브릭스] 고당도 부사사과 4kg이상(로열과/18-20입)
#
#    salePrice originalPrice               flagList totalComment numOfReviews  \
# 0      3,900         3,900        ['1+1', '오늘드림']           최고       29,223
# 1      2,430         2,700  ['2+1', '쿠폰', '오늘드림']           최고          138
# 2      3,900         3,900        ['1+1', '오늘드림']           최고           39
# 3      2,430         2,700  ['2+1', '쿠폰', '오늘드림']           최고           25
# 4      3,900         3,900        ['1+1', '오늘드림']           최고       39,368
# ..       ...           ...                    ...          ...          ...
# 95    18,960        23,700           ['쿠폰', '무배']           최고           31
# 96   105,000       105,000                     []           최고           26
# 97     7,350        10,500         ['세일', '오늘드림']           최고        1,166
# 98     3,500         3,500        ['2+1', '오늘드림']           최고        5,704
# 99    49,920        62,400           ['쿠폰', '무배']           최고          120
#
#     pctOf5  ...  pctOf1  pakingGood  pakingMiddle  pakingBad  expLong  \
# 0       87  ...       1          72            28          0       72
# 1       88  ...       0          74            26          0       70
# 2      100  ...       0          74            26          0       64
# 3       92  ...       0          80            20          0       64
# 4       85  ...       1          70            30          0       63
# ..     ...  ...     ...         ...           ...        ...      ...
# 95      97  ...       0           0             0          0        0
# 96     100  ...       0          96             4          0       88
# 97      77  ...       2          74            26          0       64
# 98      89  ...       0          71            29          1       68
# 99      91  ...       0           0             0          0        0
#
#     expMiddle  expShort  tasteGood  tasteMiddle  tasteBad
# 0          28         0         66           34         0
# 1          30         0         75           25         0
# 2          36         0         82           18         0
# 3          36         0         76           24         0
# 4          37         1         68           30         2
# ..        ...       ...        ...          ...       ...
# 95          0         0          0            0         0
# 96         12         0         88           12         0
# 97         36         0         63           28         9
# 98         32         0         76           24         1
# 99          0         0          0            0         0
#
# [100 rows x 23 columns]
